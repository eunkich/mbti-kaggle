# %%
import os.path
import pandas as pd
import numpy as np
fname = "/mbti_KK/mbti-kaggle/results/kaggle_CV_ensemble_result.csv"
os.path.isfile(fname) 

data = pd.read_csv("./results/kaggle_CV_sgd_result.csv",index_col=0)

data
# Out:
#     accuracy        f1  binary      dataset           loader method  seed  \
# 0   1.731250  1.319304   False  load_kaggle  CountVectorizer    sgd   136
# 1   0.557813  0.512611   False  load_kaggle  CountVectorizer    sgd   136
# 2   0.609821  0.587126   False  load_kaggle  CountVectorizer    sgd   136
# 3   0.609598  0.595726   False  load_kaggle  CountVectorizer    sgd   136
# 4   0.605580  0.592086   False  load_kaggle  CountVectorizer    sgd   136
# 5   0.599554  0.587386   False  load_kaggle  CountVectorizer    sgd   136
# 6   0.594643  0.581419   False  load_kaggle  CountVectorizer    sgd   136
# 7   0.590960  0.580164   False  load_kaggle  CountVectorizer    sgd   136
# 8   0.591183  0.580104   False  load_kaggle  CountVectorizer    sgd   136
# 9   0.584263  0.573946   False  load_kaggle  CountVectorizer    sgd   136
# 10  0.589844  0.580942   False  load_kaggle  CountVectorizer    sgd   136
#
#     quiet                    output  n_splits   ...    max_length  model  \
# ...

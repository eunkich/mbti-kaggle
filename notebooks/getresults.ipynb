# %%
import os.path
import pandas as pd
import numpy as np
fname = "/mbti_KK/mbti-kaggle/results/kaggle_CV_ensemble_result.csv"
os.path.isfile(fname) 

data = pd.read_csv("./results/result_table.csv",index_col=0)

data
# Out:
#                accuracy  batch_size  binary     bn             dataset device  \
# knn            0.157143          32   False  False         load_kaggle   cuda
# linear_sgd     0.490783          32   False  False         load_kaggle   cuda
# logistic       0.593433          32   False  False         load_kaggle   cuda
# naive_bayes    0.449539          32   False  False         load_kaggle   cuda
# pass_agg       0.564631          32   False  False         load_kaggle   cuda
# random_forest  0.612097          32   False  False         load_kaggle   cuda
# svc_linear     0.589171          32   False  False         load_kaggle   cuda
# xgb_class      0.644240          32   False  False         load_kaggle   cuda
# voting         0.000000          32   False  False         load_kaggle   cuda
# stacking       1.302189          32   False  False         load_kaggle   cuda
# 0              1.715625          32   False  False         load_kaggle   cuda
# 1              0.546652          32   False  False         load_kaggle   cuda
# 2              0.585491          32   False  False         load_kaggle   cuda
# 3              0.595313          32   False  False         load_kaggle   cuda
# 4              0.590402          32   False  False         load_kaggle   cuda
# 5              0.584821          32   False  False         load_kaggle   cuda
# 6              0.578125          32   False  False         load_kaggle   cuda
# 7              0.574107          32   False  False         load_kaggle   cuda
# 8              0.573549          32   False  False         load_kaggle   cuda
# 9              0.576897          32   False  False         load_kaggle   cuda
# 10             0.575335          32   False  False         load_kaggle   cuda
# knn            0.157143          32   False  False         load_kaggle   cuda
# linear_sgd     0.490783          32   False  False         load_kaggle   cuda
# logistic       0.593433          32   False  False         load_kaggle   cuda
# naive_bayes    0.449539          32   False  False         load_kaggle   cuda
# pass_agg       0.564631          32   False  False         load_kaggle   cuda
# random_forest  0.612097          32   False  False         load_kaggle   cuda
# svc_linear     0.589171          32   False  False         load_kaggle   cuda
# xgb_class      0.644240          32   False  False         load_kaggle   cuda
# voting         0.000000          32   False  False         load_kaggle   cuda
# ...                 ...         ...     ...    ...                 ...    ...
# 3              0.436272          32   False  False  load_kaggle_masked   cuda
# 4              0.434040          32   False  False  load_kaggle_masked   cuda
# 5              0.430469          32   False  False  load_kaggle_masked   cuda
# 6              0.421875          32   False  False  load_kaggle_masked   cuda
# 7              0.420982          32   False  False  load_kaggle_masked   cuda
# 8              0.414063          32   False  False  load_kaggle_masked   cuda
# 9              0.415848          32   False  False  load_kaggle_masked   cuda
# 10             0.413058          32   False  False  load_kaggle_masked   cuda
# 0              2.262500          32   False  False      load_hypertext   cuda
# 1              0.544196          32   False  False      load_hypertext   cuda
# 2              0.586607          32   False  False      load_hypertext   cuda
# 3              0.596763          32   False  False      load_hypertext   cuda
# 4              0.592969          32   False  False      load_hypertext   cuda
# 5              0.579799          32   False  False      load_hypertext   cuda
# 6              0.578348          32   False  False      load_hypertext   cuda
# 7              0.572433          32   False  False      load_hypertext   cuda
# 8              0.574554          32   False  False      load_hypertext   cuda
# 9              0.570982          32   False  False      load_hypertext   cuda
# 10             0.572991          32   False  False      load_hypertext   cuda
# 0              2.290625          32   False  False      load_hypertext   cuda
# 1              0.553906          32   False  False      load_hypertext   cuda
# 2              0.592746          32   False  False      load_hypertext   cuda
# 3              0.596429          32   False  False      load_hypertext   cuda
# 4              0.599107          32   False  False      load_hypertext   cuda
# 5              0.594643          32   False  False      load_hypertext   cuda
# 6              0.589286          32   False  False      load_hypertext   cuda
# 7              0.587835          32   False  False      load_hypertext   cuda
# 8              0.587500          32   False  False      load_hypertext   cuda
# 9              0.586049          32   False  False      load_hypertext   cuda
# 10             0.581808          32   False  False      load_hypertext   cuda
#
#                dropout  epochs        f1  hidden_dim    ...     max_length  \
# knn                NaN      10  0.148380        2048    ...            512
# linear_sgd         NaN      10  0.397300        2048    ...            512
# logistic           NaN      10  0.574087        2048    ...            512
# naive_bayes        NaN      10  0.399088        2048    ...            512
# pass_agg           NaN      10  0.535141        2048    ...            512
# random_forest      NaN      10  0.572226        2048    ...            512
# svc_linear         NaN      10  0.564224        2048    ...            512
# xgb_class          NaN      10  0.634157        2048    ...            512
# voting             NaN      10  0.000000        2048    ...            512
# stacking           NaN      10  1.260847        2048    ...            512
# 0                  NaN      10  1.483762        2048    ...            512
# 1                  NaN      10  0.502622        2048    ...            512
# 2                  NaN      10  0.563759        2048    ...            512
# 3                  NaN      10  0.579178        2048    ...            512
# 4                  NaN      10  0.577155        2048    ...            512
# 5                  NaN      10  0.570612        2048    ...            512
# 6                  NaN      10  0.566120        2048    ...            512
# 7                  NaN      10  0.562790        2048    ...            512
# 8                  NaN      10  0.562646        2048    ...            512
# 9                  NaN      10  0.565633        2048    ...            512
# 10                 NaN      10  0.562536        2048    ...            512
# knn                NaN      10  0.148380        2048    ...            512
# linear_sgd         NaN      10  0.397300        2048    ...            512
# logistic           NaN      10  0.574087        2048    ...            512
# naive_bayes        NaN      10  0.399088        2048    ...            512
# pass_agg           NaN      10  0.535141        2048    ...            512
# random_forest      NaN      10  0.572226        2048    ...            512
# svc_linear         NaN      10  0.564224        2048    ...            512
# xgb_class          NaN      10  0.634157        2048    ...            512
# voting             NaN      10  0.000000        2048    ...            512
# ...                ...     ...       ...         ...    ...            ...
# 3                  NaN      10  0.411317        2048    ...            512
# 4                  NaN      10  0.411703        2048    ...            512
# 5                  NaN      10  0.414535        2048    ...            512
# 6                  NaN      10  0.406761        2048    ...            512
# 7                  NaN      10  0.405990        2048    ...            512
# 8                  NaN      10  0.401273        2048    ...            512
# 9                  NaN      10  0.405344        2048    ...            512
# 10                 NaN      10  0.401381        2048    ...            512
# 0                  NaN      10  1.515429        2048    ...            512
# 1                  NaN      10  0.502754        2048    ...            512
# 2                  NaN      10  0.563946        2048    ...            512
# 3                  NaN      10  0.579299        2048    ...            512
# 4                  NaN      10  0.579147        2048    ...            512
# 5                  NaN      10  0.564757        2048    ...            512
# 6                  NaN      10  0.567962        2048    ...            512
# 7                  NaN      10  0.559551        2048    ...            512
# 8                  NaN      10  0.563857        2048    ...            512
# 9                  NaN      10  0.561412        2048    ...            512
# 10                 NaN      10  0.563368        2048    ...            512
# 0                  NaN      10  1.500174        2048    ...            512
# 1                  NaN      10  0.510805        2048    ...            512
# 2                  NaN      10  0.568861        2048    ...            512
# 3                  NaN      10  0.578549        2048    ...            512
# 4                  NaN      10  0.583812        2048    ...            512
# 5                  NaN      10  0.581227        2048    ...            512
# 6                  NaN      10  0.576855        2048    ...            512
# 7                  NaN      10  0.574526        2048    ...            512
# 8                  NaN      10  0.572297        2048    ...            512
# 9                  NaN      10  0.573627        2048    ...            512
# 10                 NaN      10  0.568417        2048    ...            512
#
#                  method  min_df  model  n_splits  \
# knn            ensemble     0.1   mlp3        10
# linear_sgd     ensemble     0.1   mlp3        10
# logistic       ensemble     0.1   mlp3        10
# naive_bayes    ensemble     0.1   mlp3        10
# pass_agg       ensemble     0.1   mlp3        10
# random_forest  ensemble     0.1   mlp3        10
# svc_linear     ensemble     0.1   mlp3        10
# xgb_class      ensemble     0.1   mlp3        10
# voting         ensemble     0.1   mlp3        10
# stacking       ensemble     0.1   mlp3        10
# 0                   sgd     0.1   mlp3        10
# 1                   sgd     0.1   mlp3        10
# 2                   sgd     0.1   mlp3        10
# 3                   sgd     0.1   mlp3        10
# 4                   sgd     0.1   mlp3        10
# 5                   sgd     0.1   mlp3        10
# 6                   sgd     0.1   mlp3        10
# 7                   sgd     0.1   mlp3        10
# 8                   sgd     0.1   mlp3        10
# 9                   sgd     0.1   mlp3        10
# 10                  sgd     0.1   mlp3        10
# knn            ensemble     0.1   mlp3        10
# linear_sgd     ensemble     0.1   mlp3        10
# logistic       ensemble     0.1   mlp3        10
# naive_bayes    ensemble     0.1   mlp3        10
# pass_agg       ensemble     0.1   mlp3        10
# random_forest  ensemble     0.1   mlp3        10
# svc_linear     ensemble     0.1   mlp3        10
# xgb_class      ensemble     0.1   mlp3        10
# voting         ensemble     0.1   mlp3        10
# ...                 ...     ...    ...       ...
# 3                   sgd     0.1   mlp3        10
# 4                   sgd     0.1   mlp3        10
# 5                   sgd     0.1   mlp3        10
# 6                   sgd     0.1   mlp3        10
# 7                   sgd     0.1   mlp3        10
# 8                   sgd     0.1   mlp3        10
# 9                   sgd     0.1   mlp3        10
# 10                  sgd     0.1   mlp3        10
# 0                   sgd     0.1   mlp3        10
# 1                   sgd     0.1   mlp3        10
# 2                   sgd     0.1   mlp3        10
# 3                   sgd     0.1   mlp3        10
# 4                   sgd     0.1   mlp3        10
# 5                   sgd     0.1   mlp3        10
# 6                   sgd     0.1   mlp3        10
# 7                   sgd     0.1   mlp3        10
# 8                   sgd     0.1   mlp3        10
# 9                   sgd     0.1   mlp3        10
# 10                  sgd     0.1   mlp3        10
# 0                   sgd     0.1   mlp3        10
# 1                   sgd     0.1   mlp3        10
# 2                   sgd     0.1   mlp3        10
# 3                   sgd     0.1   mlp3        10
# 4                   sgd     0.1   mlp3        10
# 5                   sgd     0.1   mlp3        10
# 6                   sgd     0.1   mlp3        10
# 7                   sgd     0.1   mlp3        10
# 8                   sgd     0.1   mlp3        10
# 9                   sgd     0.1   mlp3        10
# 10                  sgd     0.1   mlp3        10
#
#                                         output  quiet  seed verbose     weight
# knn              kaggle_CV_ensemble_result.csv  False   978    True   0.000000
# linear_sgd       kaggle_CV_ensemble_result.csv  False   978    True   0.269455
# logistic         kaggle_CV_ensemble_result.csv  False   978    True   3.580889
# naive_bayes      kaggle_CV_ensemble_result.csv  False   978    True   3.918634
# pass_agg         kaggle_CV_ensemble_result.csv  False   978    True   3.695016
# random_forest    kaggle_CV_ensemble_result.csv  False   978    True  15.457591
# svc_linear       kaggle_CV_ensemble_result.csv  False   978    True   5.618493
# xgb_class        kaggle_CV_ensemble_result.csv  False   978    True   1.727371
# voting           kaggle_CV_ensemble_result.csv  False   978    True   0.000000
# stacking         kaggle_CV_ensemble_result.csv  False   978    True   0.000000
# 0                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 1                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 2                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 3                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 4                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 5                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 6                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 7                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 8                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 9                     kaggle_CV_sgd_result.csv  False  3677    True        NaN
# 10                    kaggle_CV_sgd_result.csv  False  3677    True        NaN
# knn              kaggle_CV_ensemble_result.csv  False   978    True   0.000000
# linear_sgd       kaggle_CV_ensemble_result.csv  False   978    True   0.269455
# logistic         kaggle_CV_ensemble_result.csv  False   978    True   3.580889
# naive_bayes      kaggle_CV_ensemble_result.csv  False   978    True   3.918634
# pass_agg         kaggle_CV_ensemble_result.csv  False   978    True   3.695016
# random_forest    kaggle_CV_ensemble_result.csv  False   978    True  15.457591
# svc_linear       kaggle_CV_ensemble_result.csv  False   978    True   5.618493
# xgb_class        kaggle_CV_ensemble_result.csv  False   978    True   1.727371
# voting           kaggle_CV_ensemble_result.csv  False   978    True   0.000000
# ...                                        ...    ...   ...     ...        ...
# 3              kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 4              kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 5              kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 6              kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 7              kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 8              kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 9              kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 10             kaggle_masked_CV_sgd_result.csv  False  8277    True        NaN
# 0                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 1                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 2                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 3                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 4                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 5                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 6                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 7                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 8                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 9                  hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 10                 hypertext_CV_sgd_result.csv  False  4249    True        NaN
# 0                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 1                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 2                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 3                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 4                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 5                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 6                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 7                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 8                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 9                  hypertext_CV_sgd_result.csv  False  1003    True        NaN
# 10                 hypertext_CV_sgd_result.csv  False  1003    True        NaN
#
# [1013 rows x 25 columns]
